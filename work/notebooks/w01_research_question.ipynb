# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzamanjatoi/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shahzamanjatoi/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane is Lane 1: Ranking Signal Analysis. I chose this lane because it asks which safe, observable content and search signals (impressions, clicks, position, CTR, engagement, word count, freshness) are associated with visibility and movement. This is the natural first step before jumping into scoring or clustering, and it fits the starter dataset well since it's built for EDA and simple correlations rather than a full predictive pipeline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision this analysis could improve is which content signals a team should pay attention to when prioritizing pages for review. The action someone could take is using the signals that show the strongest association with visibility or engagement (e.g., freshness, word count, position) to guide which pages get edited first. The cost of a wrong call is spending editorial time chasing a signal that looks correlated but isn't actually meaningful, treating a weak correlation as a strong driver and revising pages that wouldn't have moved the needle anyway.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The dataset contains 30,000 content records. The average CTR is 0.5107, while the average search position is 16.34. These metrics provide an initial view of search performance and can be explored alongside impressions, clicks, content age, freshness, word count, and engagement signals to identify associations with content performance.

# %%
import pandas as pd

csv_path = "data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(csv_path)

print("Number of rows:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average position:", round(df["avg_position"].mean(), 2))
# Out:
# Number of rows: 30000
# Average CTR: 0.5107
# Average position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis can say what's observed, measured, and directional, for example that certain signals are associated with pages that later showed decline. It cannot say that any signal caused the decline, that it reflects an actual Google ranking factor, or that acting on it guarantees a recovery. All findings here are observational: I watched patterns in existing data, I did not run an experiment. Any recommendation is decision-support for a human reviewer, not a guaranteed fix.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
